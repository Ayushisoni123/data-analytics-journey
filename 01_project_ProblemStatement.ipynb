# %%
print("Indian Railways Ticket Waste Analysis")
print("Started : 2026")
print("Author : Ayushi Soni")
# Out:
# Indian Railways Ticket Waste Analysis
# Started : 2026
# Author : Ayushi Soni

# %% [markdown]
# ## Problem Statement
# I have personally travelled on Indian Railways and witnessed confirmed seats going empty while waitlisted passengers stood for hours. This happens because IRCTC's refund policy penalizes late cancellations , so passengers with confirmed tickets who cannot travel simply do not cancel.
#
# This analysis quantifies how large this problem is across major Indian railway routes.

# %%
# Libraries we will use in this project
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries loaded sucessfully")
# Out:
# Libraries loaded sucessfully
