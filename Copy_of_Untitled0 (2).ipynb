# %% [markdown]
# # Indian Railways Ticket Waste Analyzer
# ## Initial Data Exploration — September 6, 2026
#
# ### Dataset: Indian Railways Passenger Reservation Chart Data
# - 1000 journey records, 32 columns
# - Covers PNR, occupancy, cancellations, waitlist, fares, delays
#
# ### Data Source Note
# Granular seat-level cancellation data is not publicly available
# from IRCTC. This analysis uses a structured simulation dataset
# modeled on real IRCTC reservation parameters. Policy context
# figures are sourced from Indian Railways Year Book 2023-24.
#
# ### First Observation
# Average occupancy is 60.95% — meaning 39% of confirmed seats
# go unused on average while waitlisted passengers cannot board.
# This dataset will quantify the scale of this waste problem.

# %%
print("Indian Railways Ticket Waste Analysis")
print("Started : 2026")
print("Author : Ayushi Soni")
# Out:
# Indian Railways Ticket Waste Analysis
# Started : 2026
# Author : Ayushi Soni

# %%
import pandas as pd
# Load Dataset
df = pd.read_csv("indian_railway_passenger_chart.csv")

# Basic exploration
print("Dataset Shape :",df.shape)
print("\nColumns :", df.columns.tolist())
print("\nMissing values\n", df.isnull().sum())
print("\nBasic stats :\n", df.describe())
# Out:
# Dataset Shape : (1000, 32)
#
# Columns : ['PNR_Number', 'Train_Number', 'Train_Name', 'Train_Type', 'Journey_Date', 'Day_of_Week', 'Origin_Station', 'Destination_Station', 'Boarding_Station', 'Deboarding_Station', 'Class', 'Total_Capacity', 'Confirmed_Passengers', 'Waitlisted_Passengers', 'Available_Seats', 'Chart_Prepared', 'Quota_Type', 'Zone', 'Distance_KM', 'Journey_Duration_Hours', 'Base_Fare_INR', 'Tatkal_Fare_INR', 'Occupancy_Percentage', 'Season', 'Holiday_Flag', 'Cancellation_Count', 'RAC_Passengers', 'Pantry_Available', 'Platform_Number', 'Delay_Minutes', 'Punctuality_Status', 'Passenger_Satisfaction_Score']
#
# Missing values
#  PNR_Number                        0
# Train_Number                      0
# Train_Name                        0
# Train_Type                        0
# Journey_Date                      0
# Day_of_Week                       0
# Origin_Station                    0
# Destination_Station               0
# Boarding_Station                 40
# Deboarding_Station                0
# Class                             0
# Total_Capacity                    0
# Confirmed_Passengers              0
# Waitlisted_Passengers             0
# Available_Seats                   0
# Chart_Prepared                    0
# Quota_Type                        0
# Zone                              0
# Distance_KM                      50
# Journey_Duration_Hours           70
# Base_Fare_INR                     0
# Tatkal_Fare_INR                 733
# Occupancy_Percentage              0
# Season                            0
# Holiday_Flag                     30
# Cancellation_Count               50
# RAC_Passengers                   60
# Pantry_Available                  0
# Platform_Number                 120
# Delay_Minutes                    80
# Punctuality_Status                0
# Passenger_Satisfaction_Score    453
# dtype: int64
#
# Basic stats :
#         Train_Number  Total_Capacity  Confirmed_Passengers  \
# count   1000.000000     1000.000000           1000.000000
# mean   13260.698000       70.536000             42.457000
# std     2819.402356       32.058016             31.396399
# min    12019.000000       18.000000              0.000000
# 25%    12245.000000       46.000000             16.000000
# 50%    12311.000000       72.000000             37.000000
# 75%    12875.000000      100.000000             64.000000
# max    22811.000000      120.000000            120.000000
#
#        Waitlisted_Passengers  Available_Seats  Distance_KM  \
# count            1000.000000      1000.000000   950.000000
# mean                2.415000        28.079000  1293.014737
# std                 5.972809        29.150515   702.240372
# min                 0.000000         0.000000    51.000000
# 25%                 0.000000         1.000000   699.500000
# 50%                 0.000000        17.000000  1279.000000
# 75%                 0.000000        46.000000  1907.000000
# max                35.000000       120.000000  2499.000000
#
#        Journey_Duration_Hours  Base_Fare_INR  Tatkal_Fare_INR  \
# count              930.000000    1000.000000       267.000000
# mean                24.129785    2674.422000      3392.943820
# std                 13.795418    1361.071256      1758.283403
# min                  1.500000     201.000000       276.000000
# 25%                 12.300000    1478.500000      1910.000000
# 50%                 23.600000    2769.000000      3326.000000
# 75%                 36.375000    3841.000000      4961.000000
# max                 48.000000    5000.000000      6480.000000
#
#        Occupancy_Percentage  Holiday_Flag  Cancellation_Count  RAC_Passengers  \
# count            1000.00000    970.000000          950.000000      940.000000
# mean               60.95265      0.249485            4.872632        3.988298
# std                33.22148      0.432938            3.197336        2.544779
# min                 0.00000      0.000000            0.000000        0.000000
# 25%                30.95750      0.000000            2.000000        2.000000
# 50%                65.11000      0.000000            5.000000        4.000000
# 75%                97.20750      0.000000            8.000000        6.000000
# max               100.00000      1.000000           10.000000        8.000000
#
#        Platform_Number  Delay_Minutes  Passenger_Satisfaction_Score
# count       880.000000     920.000000                    547.000000
# mean          7.675000      33.451087                      3.067824
# std           4.333515      39.284512                      1.159255
# min           1.000000       0.000000                      1.000000
# 25%           4.000000       0.000000                      2.100000
# 50%           7.000000      15.000000                      3.100000
# 75%          12.000000      60.000000                      4.100000
# max          15.000000     120.000000                      5.000000

# %%
# Key metrics summary
total_journeys = len(df)
avg_occupancy = df['Occupancy_Percentage'].mean()
avg_empty_seats = df['Available_Seats'].mean()
avg_waitlisted = df['Waitlisted_Passengers'].mean()
avg_cancellations = df['Cancellation_Count'].mean()

print("=" * 50)
print("KEY FINDINGS SUMMARY")
print("=" * 50)
print(f"Total journeys analyzed: {total_journeys}")
print(f"Average occupancy: {avg_occupancy:.1f}%")
print(f"Average empty seats per journey: {avg_empty_seats:.1f}")
print(f"Average waitlisted passengers: {avg_waitlisted:.1f}")
print(f"Average cancellations per journey: {avg_cancellations:.1f}")
print(f"\nEstimated seats wasted per journey: {avg_empty_seats:.1f}")
# NOTE: 13,000 trains/day is from Indian Railways Ministry publications
# This is an external figure used to scale our sample findings nationally
# Source: Indian Railways Year Book 2023-24
print(f"Estimated annual waste (approx 13,000 trains/day):")
print(f"  {avg_empty_seats:.0f} seats x 13,000 trains = {avg_empty_seats * 13000:,.0f} empty seats daily")
# Out:
# ==================================================
# KEY FINDINGS SUMMARY
# ==================================================
# Total journeys analyzed: 1000
# Average occupancy: 61.0%
# Average empty seats per journey: 28.1
# Average waitlisted passengers: 2.4
# Average cancellations per journey: 4.9
#
# Estimated seats wasted per journey: 28.1
# Estimated annual waste (approx 13,000 trains/day):
#   28 seats x 13,000 trains = 365,027 empty seats daily

# %%
zone_occupancy = df.groupby('Zone').Occupancy_Percentage.mean()
print(zone_occupancy)
zone_occupancy_sorted = zone_occupancy.sort_values(ascending=False)
print(zone_occupancy_sorted)
# Out:
# Zone
# CR     63.922458
# ECR    61.433906
# ER     57.259754
# NER    64.177833
# NR     62.086183
# SCR    56.215702
# SR     61.407714
# WR     61.056333
# Name: Occupancy_Percentage, dtype: float64
# Zone
# NER    64.177833
# CR     63.922458
# NR     62.086183
# ECR    61.433906
# SR     61.407714
# WR     61.056333
# ER     57.259754
# SCR    56.215702
# Name: Occupancy_Percentage, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

zone_occupancy_sorted.plot(kind='bar', color='steelblue')

plt.title('Average Occupancy Percentage by Railway Zone')
plt.xlabel('Railway Zone')
plt.ylabel('Average Occupancy (%)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('zone_occupancy.png', dpi=150)
plt.show()

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
df.head()
df.shape
df.info()
df['Vaccant_Seats'] = df['Total_Capacity'] - df['Confirmed_Passengers'] - df['RAC_Passengers']
df.describe()
df.head()
(df['Vaccant_Seats'] < 0).sum()
df['Available_Seats'].equals(df['Total_Capacity']-df['Confirmed_Passengers'])
df[['Total_Capacity','Confirmed_Passengers','RAC_Passengers', 'Available_Seats']].head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 32 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   PNR_Number                    1000 non-null   object
#  1   Train_Number                  1000 non-null   int64
#  2   Train_Name                    1000 non-null   object
#  3   Train_Type                    1000 non-null   object
#  4   Journey_Date                  1000 non-null   object
#  5   Day_of_Week                   1000 non-null   object
#  6   Origin_Station                1000 non-null   object
#  7   Destination_Station           1000 non-null   object
#  8   Boarding_Station              960 non-null    object
#  9   Deboarding_Station            1000 non-null   object
#  10  Class                         1000 non-null   object
#  11  Total_Capacity                1000 non-null   int64
#  12  Confirmed_Passengers          1000 non-null   int64
#  13  Waitlisted_Passengers         1000 non-null   int64
#  14  Available_Seats               1000 non-null   int64
#  15  Chart_Prepared                1000 non-null   object
#  16  Quota_Type                    1000 non-null   object
#  17  Zone                          1000 non-null   object
#  18  Distance_KM                   950 non-null    float64
#  19  Journey_Duration_Hours        930 non-null    float64
#  20  Base_Fare_INR                 1000 non-null   int64
#  21  Tatkal_Fare_INR               267 non-null    float64
#  22  Occupancy_Percentage          1000 non-null   float64
#  23  Season                        1000 non-null   object
#  24  Holiday_Flag                  970 non-null    float64
#  25  Cancellation_Count            950 non-null    float64
#  26  RAC_Passengers                940 non-null    float64
#  27  Pantry_Available              1000 non-null   object
#  28  Platform_Number               880 non-null    float64
#  29  Delay_Minutes                 920 non-null    float64
#  30  Punctuality_Status            1000 non-null   object
#  31  Passenger_Satisfaction_Score  547 non-null    float64
# dtypes: float64(10), int64(6), object(16)
# memory usage: 250.1+ KB
#    Total_Capacity  Confirmed_Passengers  RAC_Passengers  Available_Seats
# 0              18                    18             8.0                0
# 1              72                    72             1.0                0
# 2              78                    15             3.0               63
# 3              64                    26             5.0               38
# 4              78                    78             6.0                0
# 5             120                    12             1.0              108
# 6              18                    18             5.0                0
# 7              18                     7             8.0               11
# 8              72                    72             1.0                0
# 9              46                    17             0.0               29

# %%
df[['Chart_Prepared','Quota_Type','Cancellation_Count','Zone','Train_Type','Class']].head(20)
# Out:
#    Chart_Prepared        Quota_Type  Cancellation_Count Zone Train_Type Class
# 0             Yes  Railway Employee                 3.0   NR    Express    1A
# 1             Yes            Ladies                 6.0   SR    Express    SL
# 2             Yes           Defense                 1.0   WR    Duronto    CC
# 3             Yes            Tatkal                10.0  NER    Duronto    3A
# 4              No            Tatkal                 9.0   CR   Rajdhani    CC
# 5              No    Senior Citizen                10.0  NER    Express    GN
# 6             Yes  Railway Employee                 9.0   WR    Duronto    1A
# 7              No           General                 4.0   SR       Mail    1A
# 8             Yes           General                 0.0  SCR    Duronto    SL
# 9              No            Tatkal                 7.0   NR   Rajdhani    2A
# 10            Yes    Senior Citizen                 0.0   WR   Rajdhani    2A
# 11            Yes    Senior Citizen                 2.0   CR    Express    2A
# 12            Yes            Tatkal                 1.0   NR    Duronto    1A
# 13            Yes    Senior Citizen                 1.0  SCR   Rajdhani    3A
# 14            Yes           Defense                 4.0   ER    Express    2A
# 15            Yes  Railway Employee                10.0  ECR       Mail    2A
# 16            Yes    Senior Citizen                 5.0   SR   Rajdhani    1A
# 17             No           General                 4.0   SR    Express    2S
# 18            Yes            Ladies                 0.0   NR    Express    3A
# 19            Yes            Ladies                 5.0   ER   Rajdhani    SL

# %%
df['Available_Seats'].equals(df['Total_Capacity'] - df['Confirmed_Passengers'])
df['Available_Seats'].describe()
# After analyzing we do not need the vaccant_Seat column, we are dropping it .
df = df.drop(columns = ['Vaccant_Seats'])
df.columns.tolist()
# Out:
# ['PNR_Number',
#  'Train_Number',
#  'Train_Name',
#  'Train_Type',
#  'Journey_Date',
#  'Day_of_Week',
#  'Origin_Station',
#  'Destination_Station',
#  'Boarding_Station',
#  'Deboarding_Station',
#  'Class',
#  'Total_Capacity',
#  'Confirmed_Passengers',
#  'Waitlisted_Passengers',
#  'Available_Seats',
#  'Chart_Prepared',
#  'Quota_Type',
#  'Zone',
#  'Distance_KM',
#  'Journey_Duration_Hours',
#  'Base_Fare_INR',
#  'Tatkal_Fare_INR',
#  'Occupancy_Percentage',
#  'Season',
#  'Holiday_Flag',
#  'Cancellation_Count',
#  'RAC_Passengers',
#  'Pantry_Available',
#  'Platform_Number',
#  'Delay_Minutes',
#  'Punctuality_Status',
#  'Passenger_Satisfaction_Score']

# %% [markdown]
# # **Finding 2**
#
# Average of 28 vacant seats per journey across 1000 records, with 25% of journeys having 46 or more vacant seats.

# %%
df.groupby('Season')['Occupancy_Percentage'].mean()
df.groupby(['Season', 'Holiday_Flag'])['Occupancy_Percentage'].mean()
df.groupby(['Season', 'Holiday_Flag'])['Cancellation_Count'].mean()
df.groupby(['Quota_Type'])['Occupancy_Percentage'].mean().sort_values(ascending=False)
df.groupby(['Quota_Type', 'Class'])['Occupancy_Percentage'].mean()
df.groupby(['Quota_Type', 'Class'])['Cancellation_Count'].mean()
# Out:
# Quota_Type        Class
# Defense           1A       4.629630
#                   2A       5.466667
#                   2S       4.458333
#                   3A       5.869565
#                   CC       4.968750
#                   GN       5.263158
#                   SL       5.593750
# General           1A       5.264706
#                   2A       4.085714
#                   2S       5.037037
#                   3A       4.904762
#                   CC       4.800000
#                   GN       5.230769
#                   SL       5.187500
# Ladies            1A       4.538462
#                   2A       6.052632
#                   2S       4.400000
#                   3A       6.142857
#                   CC       4.695652
#                   GN       4.793103
#                   SL       4.357143
# Railway Employee  1A       4.800000
#                   2A       5.857143
#                   2S       4.052632
#                   3A       4.909091
#                   CC       4.250000
#                   GN       4.333333
#                   SL       4.307692
# Senior Citizen    1A       3.952381
#                   2A       4.333333
#                   2S       4.421053
#                   3A       3.800000
#                   CC       5.238095
#                   GN       5.777778
#                   SL       4.772727
# Tatkal            1A       5.680000
#                   2A       3.875000
#                   2S       4.851852
#                   3A       5.833333
#                   CC       5.592593
#                   GN       4.947368
#                   SL       3.555556
# Name: Cancellation_Count, dtype: float64

# %% [markdown]
# # Finding 3
#
# - Railway Employee quota shows highest average occupancy (66.6%) while Ladies quota shows lowest (54.9%) — an 11.7 percentage point gap suggesting quota type is a stronger predictor of occupancy than season or holiday.
#
# - Ladies quota excluded from seat waste analysis — low occupancy reflects deliberate reservation policy, not inefficiency.
# - Removing Ladies quota from waste analysis, the effective seat waste problem affects 5 remaining quota types with General quota showing the most concerning pattern at 57.7% occupancy.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

zone_occupancy_sorted.plot(kind='bar', color='steelblue')

plt.title('Average Occupancy Percentage by Railway Zone')
plt.xlabel('Railway Zone')
plt.ylabel('Average Occupancy (%)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('zone_occupancy.png', dpi=150)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Available_Seats'], df['Waitlisted_Passengers'], color = 'green')

plt.title('Available Seats vs Waitlisted Passengers')
plt.xlabel('Available Seats')
plt.ylabel('Waitlisted Passengers')
plt.savefig('Available Seats vs waitlisted Passengers', dpi = 150)
plt.show()

# %% [markdown]
# ## Finding 4 — Waitlisted Passengers vs Available Seats
#
# The scatter plot reveals two distinct patterns:
#
# Pattern 1 (Top Left): High waitlisted passengers with zero available seats - these are high demand routes where confirmed
# capacity is fully allocated. These are prime candidates for a transfer mechanism if confirmed passengers do not wish to travel and does not cancel their tickets due to poor refund policy.
#
# Pattern 2 (Bottom Right): High available seats with zero
# waitlisted passengers — these are low demand routes where
# seats go unbooked entirely. This requires a different
# intervention (dynamic pricing or route marketing) rather
# than a transfer mechanism. Notably some of these may be
# essential rural connectivity routes where railways maintains
# service despite low commercial demand — shutting them is not
# viable as they serve as the only transport infrastructure
# for remote communities.
#
# Limitation: This dataset does not contain (no-show data
# directly) any specific or related columns that can show the ghost occupancy . Ghost occupancy inference requires external
# cancellation revenue data from Indian Railways publications.
